# %% [markdown]
# <a href="https://colab.research.google.com/github/F19991375/Python-problems/blob/main/greatest_common_divisor.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#ب . م . م دوعدد را با استفاده از تابع بازگشتی محاصبه کنید.
def myf(n1, n2):
  if n2 == 0:
    return n1
  return myf(n2, n1 % n2)

# %%
myf(12, 8)
# Out:
# 4
